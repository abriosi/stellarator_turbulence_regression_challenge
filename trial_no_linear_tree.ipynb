# %%
import shap
import pickle
import optuna
import numpy as np
import lightgbm as lgb
import optuna.integration
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, root_mean_squared_error

# File with the flux tube geometries (features):
in_filename = "20240601-01-assembleFluxTubeMatrix_normalizeMeanStdIndependentOfZ_withAndWithoutCvdrift_nz97_withCvdrift.pkl"
# File with the GX heat flux
out_filename = "20240601-01-103_gx_nfp4_production_gx_results.pkl"

with open(in_filename, "rb") as f:
    in_data = pickle.load(f)

with open(out_filename, "rb") as f:
    out_data = pickle.load(f)

X = in_data["matrix"]
heat_flux_averages = out_data["Q_avgs"]

# %%
in_data.keys()
# Out:
# dict_keys(['tube_files', 'nl', 'z_functions', 'scalars', 'n_features', 'n_quantities', 'n_tubes', 'matrix', 'means', 'standard_deviations'])

# %%
in_data["matrix"]
# Out:
# array([[ 0.02278433,  0.79329694,  0.47829241, ..., -0.85963928,
#         -0.8744202 , -0.80227028],
#        [ 1.87583922,  1.81435098,  0.96975006, ...,  0.95706323,
#          0.87230722,  0.27335504],
#        [ 0.43586769,  1.80462561,  1.59276536, ..., -0.4965529 ,
#         -0.77648957, -0.89956508],
#        ...,
#        [ 0.13053565, -0.7773523 , -0.59668751, ..., -0.37490712,
#         -0.62196128, -0.69224254],
#        [-1.35382024, -0.85957927, -0.1629058 , ...,  2.14119896,
#          2.06968399,  1.78776422],
#        [-0.31146954, -0.13072943, -0.79157277, ...,  1.37519525,
#          1.23457818,  0.48518993]])

# %%
out_data["Q_avgs"]
# Out:
# array([ 9.75939  ,  9.549901 , 11.110395 , ..., 16.632994 ,  7.2723794,
#        16.234438 ], dtype=float32)

# %%
features = in_data["matrix"]
target = np.log(out_data["Q_avgs"])

train_x, valid_x, train_y, valid_y = train_test_split(features, target, test_size=0.2, random_state=1337)

# %%
# Define the objective function
def objective(trial):

    dtrain = lgb.Dataset(train_x, label=train_y)
    dvalid = lgb.Dataset(valid_x, label=valid_y, reference=dtrain)

    param = {
        'objective': trial.suggest_categorical("objective", ["regression_l2", "regression_l1"]),
        'metric': 'rmse',
        'verbosity': -1,
        'boosting_type': trial.suggest_categorical("boosting_type", ["gbdt", "rf", "dart"]),
        #'linear_tree': trial.suggest_categorical("linear_tree", [True, False]),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 2, 512),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.1, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.1, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1.0, log=True),
        'max_depth': trial.suggest_int('max_depth', -1, 50),
        'min_split_gain': trial.suggest_float('min_split_gain', 0.0, 1.0),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'num_iterations': trial.suggest_int('num_iterations', 10, 1000)
    }

    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, 'rmse')

    gbm = lgb.train(param, dtrain, valid_sets=[dvalid], callbacks=[pruning_callback])

    preds = gbm.predict(valid_x)
    r2 = r2_score(valid_y, preds)
    
    return -r2

# Create a study object and optimize the objective function
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=500)

# Display the best hyperparameters
print('Best hyperparameters: ', study.best_params)
# Out:
# [I 2024-06-12 11:28:35,613] A new study created in memory with name: no-name-26e3c1d2-9bb7-4e29-8a2d-35448f348e2e
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:28:38,595] Trial 0 finished with value: -0.6260811148072407 and parameters: {'objective': 'regression_l1', 'boosting_type': 'gbdt', 'lambda_l1': 4.850105914354394e-08, 'lambda_l2': 0.0019300478031530096, 'num_leaves': 494, 'feature_fraction': 0.5981044881660155, 'bagging_fraction': 0.36281230786685703, 'bagging_freq': 2, 'min_child_samples': 74, 'learning_rate': 0.2649364659272982, 'max_depth': 31, 'min_split_gain': 0.24497630244284374, 'subsample': 0.3634007335380034, 'colsample_bytree': 0.46732807154711287, 'num_iterations': 383}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:28:51,468] Trial 1 finished with value: -0.3818610124372164 and parameters: {'objective': 'regression_l1', 'boosting_type': 'rf', 'lambda_l1': 0.4366183276821734, 'lambda_l2': 8.134746144792857e-08, 'num_leaves': 177, 'feature_fraction': 0.3654561038557046, 'bagging_fraction': 0.8991063145793945, 'bagging_freq': 4, 'min_child_samples': 41, 'learning_rate': 0.00041330772987094777, 'max_depth': 42, 'min_split_gain': 0.24851095297808867, 'subsample': 0.39862966109317843, 'colsample_bytree': 0.514765270384678, 'num_iterations': 610}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:28:52,515] Trial 2 finished with value: 4.805508234986748 and parameters: {'objective': 'regression_l1', 'boosting_type': 'dart', 'lambda_l1': 7.11125606292072e-05, 'lambda_l2': 0.64972535401935, 'num_leaves': 462, 'feature_fraction': 0.4315914970129281, 'bagging_fraction': 0.6924760235539088, 'bagging_freq': 2, 'min_child_samples': 57, 'learning_rate': 8.584332119532987e-05, 'max_depth': 3, 'min_split_gain': 0.5918524517343382, 'subsample': 0.8353822150277586, 'colsample_bytree': 0.4649107665342478, 'num_iterations': 254}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:28:57,165] Trial 3 finished with value: 4.514490095029265 and parameters: {'objective': 'regression_l1', 'boosting_type': 'dart', 'lambda_l1': 1.5876818914937043e-07, 'lambda_l2': 1.1888409493567124e-08, 'num_leaves': 332, 'feature_fraction': 0.9818044761067952, 'bagging_fraction': 0.1638804868831846, 'bagging_freq': 5, 'min_child_samples': 17, 'learning_rate': 0.0008418197550111888, 'max_depth': 43, 'min_split_gain': 0.6492040339795913, 'subsample': 0.4053147864523856, 'colsample_bytree': 0.13771447563091782, 'num_iterations': 727}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:29:07,649] Trial 4 finished with value: 0.2445751930144584 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 0.0003419275317334231, 'lambda_l2': 1.5636250402152705, 'num_leaves': 380, 'feature_fraction': 0.14434775280662251, 'bagging_fraction': 0.6675298015602673, 'bagging_freq': 7, 'min_child_samples': 82, 'learning_rate': 0.005410539423005977, 'max_depth': 12, 'min_split_gain': 0.6287072219669617, 'subsample': 0.22578590807769205, 'colsample_bytree': 0.1442516104607381, 'num_iterations': 938}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:29:07,823] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:29:08,105] Trial 6 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:26,247] Trial 7 finished with value: -0.39358859310633587 and parameters: {'objective': 'regression_l1', 'boosting_type': 'rf', 'lambda_l1': 6.0179385050528376e-05, 'lambda_l2': 0.39155149961146585, 'num_leaves': 275, 'feature_fraction': 0.9902971173333406, 'bagging_fraction': 0.8579783029834555, 'bagging_freq': 10, 'min_child_samples': 4, 'learning_rate': 4.5634344793566884e-05, 'max_depth': 18, 'min_split_gain': 0.3027812566995267, 'subsample': 0.7264254111345625, 'colsample_bytree': 0.629146039020325, 'num_iterations': 607}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:30:26,432] Trial 8 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:26,692] Trial 9 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:32,382] Trial 10 finished with value: -0.5457940665742447 and parameters: {'objective': 'regression_l1', 'boosting_type': 'gbdt', 'lambda_l1': 4.6622135865677094e-08, 'lambda_l2': 1.3875880262472106e-05, 'num_leaves': 82, 'feature_fraction': 0.7992005962879674, 'bagging_fraction': 0.36107530109880837, 'bagging_freq': 1, 'min_child_samples': 38, 'learning_rate': 0.4396611482514018, 'max_depth': 18, 'min_split_gain': 0.041979440274004576, 'subsample': 0.5789401461007729, 'colsample_bytree': 0.7456534843898289, 'num_iterations': 352}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:30:39,044] Trial 11 finished with value: -0.35938571016505105 and parameters: {'objective': 'regression_l1', 'boosting_type': 'gbdt', 'lambda_l1': 1.0256662199355501e-08, 'lambda_l2': 1.2994386703921639e-05, 'num_leaves': 42, 'feature_fraction': 0.7915449888889265, 'bagging_fraction': 0.3794484053546344, 'bagging_freq': 1, 'min_child_samples': 36, 'learning_rate': 0.6146249657583027, 'max_depth': 18, 'min_split_gain': 0.0062559941953182485, 'subsample': 0.5560521384004989, 'colsample_bytree': 0.7432012771583745, 'num_iterations': 379}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:30:43,093] Trial 12 finished with value: -0.1422001900160349 and parameters: {'objective': 'regression_l1', 'boosting_type': 'gbdt', 'lambda_l1': 9.168599460305806e-07, 'lambda_l2': 4.548521607859166e-05, 'num_leaves': 129, 'feature_fraction': 0.8474566563511766, 'bagging_fraction': 0.4295380969893679, 'bagging_freq': 1, 'min_child_samples': 37, 'learning_rate': 0.7790954209651282, 'max_depth': 6, 'min_split_gain': 0.03103976665509207, 'subsample': 0.657491337301106, 'colsample_bytree': 0.8288804627504152, 'num_iterations': 432}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:30:43,265] Trial 13 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:43,494] Trial 14 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:43,724] Trial 15 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:43,949] Trial 16 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:44,167] Trial 17 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:30:44,389] Trial 18 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:44,613] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:44,978] Trial 20 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:45,545] Trial 21 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:30:45,796] Trial 22 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:30:46,049] Trial 23 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:30:46,354] Trial 24 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:30:46,677] Trial 25 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:30:46,902] Trial 26 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:30:47,167] Trial 27 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:30:47,393] Trial 28 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:00,126] Trial 29 finished with value: -0.3878518432541551 and parameters: {'objective': 'regression_l1', 'boosting_type': 'rf', 'lambda_l1': 0.001962090521147579, 'lambda_l2': 9.664619820951347e-08, 'num_leaves': 158, 'feature_fraction': 0.30453159774774624, 'bagging_fraction': 0.8612418344725344, 'bagging_freq': 9, 'min_child_samples': 41, 'learning_rate': 0.14847060400718295, 'max_depth': 35, 'min_split_gain': 0.23561418661404362, 'subsample': 0.41589369131139875, 'colsample_bytree': 0.8790991681554617, 'num_iterations': 638}. Best is trial 0 with value: -0.6260811148072407.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:00,321] Trial 30 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:00,731] Trial 31 pruned. Trial was pruned at iteration 10.
# [I 2024-06-12 11:31:01,138] Trial 32 pruned. Trial was pruned at iteration 8.
# [I 2024-06-12 11:31:01,328] Trial 33 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:01,629] Trial 34 pruned. Trial was pruned at iteration 10.
# [I 2024-06-12 11:31:01,932] Trial 35 pruned. Trial was pruned at iteration 5.
# [I 2024-06-12 11:31:02,196] Trial 36 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:02,727] Trial 37 pruned. Trial was pruned at iteration 8.
# [I 2024-06-12 11:31:02,981] Trial 38 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:15,324] Trial 39 finished with value: -0.6514282225115378 and parameters: {'objective': 'regression_l1', 'boosting_type': 'gbdt', 'lambda_l1': 0.000588046410369545, 'lambda_l2': 8.774593409299056e-07, 'num_leaves': 423, 'feature_fraction': 0.946450969097512, 'bagging_fraction': 0.9438943257814343, 'bagging_freq': 2, 'min_child_samples': 64, 'learning_rate': 0.43147405478498924, 'max_depth': 28, 'min_split_gain': 0.16212762719456425, 'subsample': 0.4405541030861012, 'colsample_bytree': 0.28969098448693464, 'num_iterations': 470}. Best is trial 39 with value: -0.6514282225115378.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:16,567] Trial 40 finished with value: -0.5742624234520751 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 3.665041479323506e-08, 'lambda_l2': 8.279733245217609e-07, 'num_leaves': 415, 'feature_fraction': 0.9508847782611713, 'bagging_fraction': 0.9454201863368272, 'bagging_freq': 2, 'min_child_samples': 64, 'learning_rate': 0.5074549116233327, 'max_depth': 21, 'min_split_gain': 0.1544030376540063, 'subsample': 0.6586004162420431, 'colsample_bytree': 0.24519434725791892, 'num_iterations': 460}. Best is trial 39 with value: -0.6514282225115378.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:17,817] Trial 41 finished with value: -0.5631764039880709 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 3.415844187461488e-08, 'lambda_l2': 1.6736493627794265e-06, 'num_leaves': 414, 'feature_fraction': 0.953209126758062, 'bagging_fraction': 0.9260266776301164, 'bagging_freq': 2, 'min_child_samples': 64, 'learning_rate': 0.47945952891288746, 'max_depth': 28, 'min_split_gain': 0.15877048423717835, 'subsample': 0.6478572320323915, 'colsample_bytree': 0.24912836737641225, 'num_iterations': 451}. Best is trial 39 with value: -0.6514282225115378.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:19,136] Trial 42 finished with value: -0.6003581153966718 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 3.9954842806281794e-08, 'lambda_l2': 6.749402305101206e-07, 'num_leaves': 418, 'feature_fraction': 0.949451771752907, 'bagging_fraction': 0.941990707518261, 'bagging_freq': 2, 'min_child_samples': 75, 'learning_rate': 0.4571712929020977, 'max_depth': 29, 'min_split_gain': 0.0828440534422447, 'subsample': 0.6547245658329175, 'colsample_bytree': 0.2716788964378367, 'num_iterations': 409}. Best is trial 39 with value: -0.6514282225115378.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:19,576] Trial 43 pruned. Trial was pruned at iteration 14.
# [I 2024-06-12 11:31:21,017] Trial 44 finished with value: -0.5815048015550519 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 2.9095225512698196e-07, 'lambda_l2': 1.7241108910528546e-06, 'num_leaves': 458, 'feature_fraction': 0.953138305135872, 'bagging_fraction': 0.9611467267720701, 'bagging_freq': 3, 'min_child_samples': 66, 'learning_rate': 0.44549208963288306, 'max_depth': 26, 'min_split_gain': 0.07323866690093231, 'subsample': 0.6179072935894068, 'colsample_bytree': 0.26764493314965315, 'num_iterations': 410}. Best is trial 39 with value: -0.6514282225115378.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:21,239] Trial 45 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:21,542] Trial 46 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:23,487] Trial 47 finished with value: -0.5433566687762841 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 1.8138164443607603e-06, 'lambda_l2': 3.4645900062198694e-08, 'num_leaves': 489, 'feature_fraction': 0.9613014148608802, 'bagging_fraction': 0.9995107789914687, 'bagging_freq': 1, 'min_child_samples': 57, 'learning_rate': 0.6192266680466801, 'max_depth': 33, 'min_split_gain': 0.006259992943321913, 'subsample': 0.7528529011881874, 'colsample_bytree': 0.16932388108493646, 'num_iterations': 318}. Best is trial 39 with value: -0.6514282225115378.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:23,695] Trial 48 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:23,979] Trial 49 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:24,299] Trial 50 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:31:25,641] Trial 51 finished with value: -0.5860805971986229 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 2.5076690679744404e-08, 'lambda_l2': 1.1103099050689822e-06, 'num_leaves': 410, 'feature_fraction': 0.9578962700623694, 'bagging_fraction': 0.9018883935743734, 'bagging_freq': 2, 'min_child_samples': 66, 'learning_rate': 0.4429760761799587, 'max_depth': 28, 'min_split_gain': 0.16873843096120034, 'subsample': 0.6399785674782561, 'colsample_bytree': 0.2796929948231367, 'num_iterations': 466}. Best is trial 39 with value: -0.6514282225115378.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:26,662] Trial 52 pruned. Trial was pruned at iteration 269.
# [I 2024-06-12 11:31:27,011] Trial 53 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:27,300] Trial 54 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:27,892] Trial 55 pruned. Trial was pruned at iteration 35.
# [I 2024-06-12 11:31:28,176] Trial 56 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:31,600] Trial 57 finished with value: -0.6900649320105294 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 1.6298131009054763e-08, 'lambda_l2': 5.1183377428232224e-05, 'num_leaves': 404, 'feature_fraction': 0.9734668467978245, 'bagging_fraction': 0.9614032655806881, 'bagging_freq': 3, 'min_child_samples': 77, 'learning_rate': 0.419360662312226, 'max_depth': 32, 'min_split_gain': 0.1080826161857542, 'subsample': 0.5879430093931554, 'colsample_bytree': 0.24682769114111947, 'num_iterations': 263}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:31,806] Trial 58 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:32,063] Trial 59 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:32,331] Trial 60 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:37,066] Trial 61 finished with value: -0.6819200303292317 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 5.100927388067872e-08, 'lambda_l2': 9.913808771517504e-06, 'num_leaves': 404, 'feature_fraction': 0.9416165586249446, 'bagging_fraction': 0.9464805907832208, 'bagging_freq': 2, 'min_child_samples': 87, 'learning_rate': 0.6204106476959944, 'max_depth': 28, 'min_split_gain': 0.050018536325830296, 'subsample': 0.7571096512586033, 'colsample_bytree': 0.22250559742589343, 'num_iterations': 345}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:41,584] Trial 62 finished with value: -0.6788339308344961 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 9.273825447042422e-08, 'lambda_l2': 0.00015528692617788835, 'num_leaves': 398, 'feature_fraction': 0.8981004131849667, 'bagging_fraction': 0.9609704291437168, 'bagging_freq': 2, 'min_child_samples': 87, 'learning_rate': 0.6308041236408172, 'max_depth': 28, 'min_split_gain': 0.05413144967219233, 'subsample': 0.8000275602753768, 'colsample_bytree': 0.22571018156368708, 'num_iterations': 340}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:41,864] Trial 63 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:31:42,149] Trial 64 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:42,509] Trial 65 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:31:42,782] Trial 66 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:43,062] Trial 67 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:44,165] Trial 68 finished with value: -0.6359124212323484 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 6.818404532508811e-07, 'lambda_l2': 7.162740478928602e-06, 'num_leaves': 432, 'feature_fraction': 0.9133110898172873, 'bagging_fraction': 0.7923108663957684, 'bagging_freq': 1, 'min_child_samples': 82, 'learning_rate': 0.685874567851852, 'max_depth': 24, 'min_split_gain': 0.9521255958977599, 'subsample': 0.7427572440822491, 'colsample_bytree': 0.3436026997621628, 'num_iterations': 210}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:44,384] Trial 69 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:44,679] Trial 70 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:44,987] Trial 71 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:45,312] Trial 72 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:31:45,593] Trial 73 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:45,889] Trial 74 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:31:46,174] Trial 75 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:46,465] Trial 76 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:46,752] Trial 77 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:47,032] Trial 78 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:47,330] Trial 79 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:47,621] Trial 80 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:49,082] Trial 81 finished with value: -0.5961934306191348 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 2.693103353744616e-07, 'lambda_l2': 1.5015211690581875e-06, 'num_leaves': 451, 'feature_fraction': 0.9555827170891381, 'bagging_fraction': 0.9535167333050728, 'bagging_freq': 3, 'min_child_samples': 68, 'learning_rate': 0.4293153889144156, 'max_depth': 26, 'min_split_gain': 0.06392566961611243, 'subsample': 0.621188272154257, 'colsample_bytree': 0.26237610182256044, 'num_iterations': 420}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:50,600] Trial 82 finished with value: -0.5699394644118789 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 1.3311897107041162e-07, 'lambda_l2': 1.2478773655197808e-06, 'num_leaves': 451, 'feature_fraction': 0.9980603960828311, 'bagging_fraction': 0.9519083185877045, 'bagging_freq': 3, 'min_child_samples': 69, 'learning_rate': 0.5313607226951551, 'max_depth': 25, 'min_split_gain': 0.05464280545695598, 'subsample': 0.6951103582326722, 'colsample_bytree': 0.2961973548259932, 'num_iterations': 474}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:50,834] Trial 83 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:51,119] Trial 84 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:51,459] Trial 85 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:31:51,754] Trial 86 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:52,074] Trial 87 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:53,391] Trial 88 finished with value: -0.5686188372448209 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 1.0368054825435784e-08, 'lambda_l2': 2.6461692637969656e-07, 'num_leaves': 424, 'feature_fraction': 0.8549762787575282, 'bagging_fraction': 0.9094335177535906, 'bagging_freq': 2, 'min_child_samples': 67, 'learning_rate': 0.49551305796843437, 'max_depth': 24, 'min_split_gain': 0.28312087704839545, 'subsample': 0.6345350162093513, 'colsample_bytree': 0.31197784233547027, 'num_iterations': 513}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:53,637] Trial 89 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:53,923] Trial 90 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:54,240] Trial 91 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:54,587] Trial 92 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:31:54,882] Trial 93 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:55,190] Trial 94 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:55,581] Trial 95 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:55,932] Trial 96 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:31:56,205] Trial 97 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:56,458] Trial 98 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:56,761] Trial 99 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:57,156] Trial 100 pruned. Trial was pruned at iteration 5.
# [I 2024-06-12 11:31:58,478] Trial 101 finished with value: -0.5933059973260701 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 1.368127219625056e-08, 'lambda_l2': 9.946766863656418e-07, 'num_leaves': 416, 'feature_fraction': 0.9854799154717814, 'bagging_fraction': 0.945352248525905, 'bagging_freq': 2, 'min_child_samples': 58, 'learning_rate': 0.4610953453216108, 'max_depth': 20, 'min_split_gain': 0.16904294564418365, 'subsample': 0.6621580133055389, 'colsample_bytree': 0.22337185928269374, 'num_iterations': 463}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:31:58,738] Trial 102 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:31:59,037] Trial 103 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:59,319] Trial 104 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:31:59,612] Trial 105 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:00,185] Trial 106 pruned. Trial was pruned at iteration 13.
# [I 2024-06-12 11:32:00,540] Trial 107 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:00,941] Trial 108 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:01,247] Trial 109 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:01,591] Trial 110 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:03,101] Trial 111 finished with value: -0.5941288736878658 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 3.18071593486078e-08, 'lambda_l2': 7.478838487362015e-07, 'num_leaves': 396, 'feature_fraction': 0.9854617724525228, 'bagging_fraction': 0.9495581983803266, 'bagging_freq': 2, 'min_child_samples': 62, 'learning_rate': 0.4611450464407876, 'max_depth': 21, 'min_split_gain': 0.15386484753219914, 'subsample': 0.6424443798421807, 'colsample_bytree': 0.22109193851927814, 'num_iterations': 521}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:32:04,627] Trial 112 finished with value: -0.5915062816049713 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 2.5096451448059822e-08, 'lambda_l2': 9.251653588919233e-07, 'num_leaves': 395, 'feature_fraction': 0.9471010357295209, 'bagging_fraction': 0.9558432600644041, 'bagging_freq': 2, 'min_child_samples': 53, 'learning_rate': 0.45551159220090276, 'max_depth': 21, 'min_split_gain': 0.14927464631172777, 'subsample': 0.6321328506293065, 'colsample_bytree': 0.21643600482942882, 'num_iterations': 526}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:32:04,891] Trial 113 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:05,200] Trial 114 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:05,525] Trial 115 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:05,837] Trial 116 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:06,173] Trial 117 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:06,456] Trial 118 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:06,733] Trial 119 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:07,061] Trial 120 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:08,596] Trial 121 finished with value: -0.5904326993490652 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 1.5903595401005906e-07, 'lambda_l2': 6.099286327769999e-07, 'num_leaves': 442, 'feature_fraction': 0.9648646590292109, 'bagging_fraction': 0.9641430706141558, 'bagging_freq': 3, 'min_child_samples': 57, 'learning_rate': 0.43050902873746405, 'max_depth': 28, 'min_split_gain': 0.06955695692533218, 'subsample': 0.6163058941765082, 'colsample_bytree': 0.2552965564137012, 'num_iterations': 423}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:32:08,840] Trial 122 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:09,149] Trial 123 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:09,524] Trial 124 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:09,769] Trial 125 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:10,009] Trial 126 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:10,324] Trial 127 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:10,628] Trial 128 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:11,082] Trial 129 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:11,548] Trial 130 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:32:12,070] Trial 131 pruned. Trial was pruned at iteration 7.
# [I 2024-06-12 11:32:12,386] Trial 132 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:12,705] Trial 133 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:13,013] Trial 134 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:13,377] Trial 135 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:13,686] Trial 136 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:14,168] Trial 137 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:32:14,494] Trial 138 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:14,752] Trial 139 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:15,017] Trial 140 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:15,261] Trial 141 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:15,587] Trial 142 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:15,997] Trial 143 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:32:16,331] Trial 144 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:16,605] Trial 145 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:16,952] Trial 146 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:17,268] Trial 147 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:17,573] Trial 148 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:17,875] Trial 149 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:18,165] Trial 150 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:18,504] Trial 151 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:18,834] Trial 152 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:19,338] Trial 153 pruned. Trial was pruned at iteration 7.
# [I 2024-06-12 11:32:19,679] Trial 154 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:20,022] Trial 155 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:20,321] Trial 156 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:20,635] Trial 157 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:20,938] Trial 158 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:21,255] Trial 159 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:21,606] Trial 160 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:21,988] Trial 161 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:32:22,373] Trial 162 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:22,782] Trial 163 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:24,035] Trial 164 finished with value: -0.5807832308206642 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 4.423250675820804e-08, 'lambda_l2': 3.516386152230347e-07, 'num_leaves': 423, 'feature_fraction': 0.9644093270753197, 'bagging_fraction': 0.8945592569939373, 'bagging_freq': 2, 'min_child_samples': 58, 'learning_rate': 0.4470045009236762, 'max_depth': 24, 'min_split_gain': 0.23463039447414455, 'subsample': 0.647926993953071, 'colsample_bytree': 0.2289339977635645, 'num_iterations': 398}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:32:24,287] Trial 165 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:24,606] Trial 166 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:24,937] Trial 167 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:25,268] Trial 168 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:25,687] Trial 169 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:25,964] Trial 170 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:26,629] Trial 171 pruned. Trial was pruned at iteration 52.
# [I 2024-06-12 11:32:28,247] Trial 172 finished with value: -0.5954910372437807 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 2.5596077220080224e-08, 'lambda_l2': 2.818611212128159e-07, 'num_leaves': 423, 'feature_fraction': 0.9206329762875435, 'bagging_fraction': 0.9473406552280549, 'bagging_freq': 2, 'min_child_samples': 67, 'learning_rate': 0.4601119430447249, 'max_depth': 24, 'min_split_gain': 0.12075492617267986, 'subsample': 0.6621297974139269, 'colsample_bytree': 0.33040411500358, 'num_iterations': 517}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:32:28,487] Trial 173 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:28,843] Trial 174 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:29,175] Trial 175 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:29,544] Trial 176 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:29,850] Trial 177 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:30,150] Trial 178 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:30,452] Trial 179 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:30,838] Trial 180 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:32:31,164] Trial 181 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:31,504] Trial 182 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:31,808] Trial 183 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:32,146] Trial 184 pruned. Trial was pruned at iteration 5.
# [I 2024-06-12 11:32:32,440] Trial 185 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:32,740] Trial 186 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:33,043] Trial 187 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:33,388] Trial 188 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:33,686] Trial 189 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:34,028] Trial 190 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:34,328] Trial 191 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:34,622] Trial 192 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:35,093] Trial 193 pruned. Trial was pruned at iteration 10.
# [I 2024-06-12 11:32:35,356] Trial 194 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:35,731] Trial 195 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:32:36,043] Trial 196 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:36,363] Trial 197 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:36,717] Trial 198 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:32:36,979] Trial 199 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:37,297] Trial 200 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:37,594] Trial 201 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:37,874] Trial 202 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:38,176] Trial 203 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:38,471] Trial 204 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:38,777] Trial 205 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:39,099] Trial 206 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:39,376] Trial 207 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:39,622] Trial 208 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:39,952] Trial 209 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:40,242] Trial 210 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:40,615] Trial 211 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:32:41,253] Trial 212 pruned. Trial was pruned at iteration 11.
# [I 2024-06-12 11:32:41,637] Trial 213 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:42,013] Trial 214 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:42,443] Trial 215 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:42,771] Trial 216 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:43,103] Trial 217 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:43,398] Trial 218 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:43,790] Trial 219 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:32:44,109] Trial 220 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:44,475] Trial 221 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:44,960] Trial 222 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:45,299] Trial 223 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:45,606] Trial 224 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:45,962] Trial 225 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:46,302] Trial 226 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:46,587] Trial 227 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:46,846] Trial 228 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:47,157] Trial 229 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:47,431] Trial 230 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:47,725] Trial 231 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:48,033] Trial 232 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:48,312] Trial 233 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:48,577] Trial 234 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:48,789] Trial 235 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:49,017] Trial 236 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:49,263] Trial 237 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:49,532] Trial 238 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:49,805] Trial 239 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:50,084] Trial 240 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:50,332] Trial 241 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:50,568] Trial 242 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:50,847] Trial 243 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:32:51,134] Trial 244 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:51,457] Trial 245 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:51,727] Trial 246 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:52,026] Trial 247 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:52,507] Trial 248 pruned. Trial was pruned at iteration 5.
# [I 2024-06-12 11:32:53,761] Trial 249 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:32:54,060] Trial 250 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:54,503] Trial 251 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:54,807] Trial 252 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:55,200] Trial 253 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:55,493] Trial 254 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:55,770] Trial 255 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:32:58,816] Trial 256 finished with value: -0.6838137735108247 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 3.237380660446439e-07, 'lambda_l2': 1.6975209215566013e-05, 'num_leaves': 463, 'feature_fraction': 0.9182395739599695, 'bagging_fraction': 0.8877009063536399, 'bagging_freq': 3, 'min_child_samples': 65, 'learning_rate': 0.5405470561392764, 'max_depth': 30, 'min_split_gain': 0.1818474327986974, 'subsample': 0.3847761124197372, 'colsample_bytree': 0.7735129904471516, 'num_iterations': 307}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:32:59,184] Trial 257 pruned. Trial was pruned at iteration 6.
# [I 2024-06-12 11:32:59,641] Trial 258 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:32:59,983] Trial 259 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:33:02,910] Trial 260 finished with value: -0.6817867721681166 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 1.976136210185643e-08, 'lambda_l2': 1.0949907064600752e-05, 'num_leaves': 454, 'feature_fraction': 0.9281415983792473, 'bagging_fraction': 0.9570089623605161, 'bagging_freq': 3, 'min_child_samples': 69, 'learning_rate': 0.48135690929542363, 'max_depth': 24, 'min_split_gain': 0.1850146537834873, 'subsample': 0.379220920353477, 'colsample_bytree': 0.7836975252145949, 'num_iterations': 276}. Best is trial 57 with value: -0.6900649320105294.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:33:03,253] Trial 261 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:33:03,640] Trial 262 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:04,049] Trial 263 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:33:04,370] Trial 264 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:07,390] Trial 265 finished with value: -0.6993705928115532 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 3.82633509271862e-08, 'lambda_l2': 6.51512044541533e-05, 'num_leaves': 439, 'feature_fraction': 0.49162472859382134, 'bagging_fraction': 0.9219824165177758, 'bagging_freq': 2, 'min_child_samples': 65, 'learning_rate': 0.5199887797749565, 'max_depth': 21, 'min_split_gain': 0.1576217695589074, 'subsample': 0.654661529996304, 'colsample_bytree': 0.7879778688270193, 'num_iterations': 330}. Best is trial 265 with value: -0.6993705928115532.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:33:10,397] Trial 266 finished with value: -0.6993641101009764 and parameters: {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 4.379957054025638e-08, 'lambda_l2': 6.131600101349175e-05, 'num_leaves': 445, 'feature_fraction': 0.49041817281718014, 'bagging_fraction': 0.9231981601820349, 'bagging_freq': 2, 'min_child_samples': 63, 'learning_rate': 0.5034694442198924, 'max_depth': 21, 'min_split_gain': 0.15613685161895108, 'subsample': 0.6550559754292655, 'colsample_bytree': 0.7366868832140852, 'num_iterations': 331}. Best is trial 265 with value: -0.6993705928115532.
# ...
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:33:43,448] Trial 318 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:33:43,774] Trial 319 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:44,077] Trial 320 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:44,377] Trial 321 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:44,757] Trial 322 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:33:45,058] Trial 323 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:45,393] Trial 324 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:45,703] Trial 325 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:46,021] Trial 326 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:46,382] Trial 327 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:33:46,699] Trial 328 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:47,103] Trial 329 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:33:47,411] Trial 330 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:47,731] Trial 331 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:48,212] Trial 332 pruned. Trial was pruned at iteration 7.
# [I 2024-06-12 11:33:48,585] Trial 333 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:33:48,918] Trial 334 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:49,221] Trial 335 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:49,592] Trial 336 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:33:49,964] Trial 337 pruned. Trial was pruned at iteration 15.
# [I 2024-06-12 11:33:50,263] Trial 338 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:50,622] Trial 339 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:33:50,972] Trial 340 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:51,271] Trial 341 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:51,557] Trial 342 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:51,815] Trial 343 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:52,176] Trial 344 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:33:52,553] Trial 345 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:52,894] Trial 346 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:53,512] Trial 347 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:53,962] Trial 348 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:33:54,296] Trial 349 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:54,637] Trial 350 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:33:54,962] Trial 351 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:55,274] Trial 352 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:55,782] Trial 353 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:33:56,096] Trial 354 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:56,399] Trial 355 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:56,753] Trial 356 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:33:57,115] Trial 357 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:33:57,434] Trial 358 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:57,745] Trial 359 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:58,165] Trial 360 pruned. Trial was pruned at iteration 5.
# [I 2024-06-12 11:33:58,461] Trial 361 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:58,831] Trial 362 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:33:59,182] Trial 363 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:59,544] Trial 364 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:33:59,901] Trial 365 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:00,320] Trial 366 pruned. Trial was pruned at iteration 5.
# [I 2024-06-12 11:34:00,667] Trial 367 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:01,005] Trial 368 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:01,335] Trial 369 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:01,672] Trial 370 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:02,063] Trial 371 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:02,408] Trial 372 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:02,776] Trial 373 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:03,112] Trial 374 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:03,444] Trial 375 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:03,773] Trial 376 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:04,089] Trial 377 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:04,444] Trial 378 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:04,836] Trial 379 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:05,218] Trial 380 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:05,526] Trial 381 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:05,859] Trial 382 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:06,180] Trial 383 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:06,523] Trial 384 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:06,890] Trial 385 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:07,230] Trial 386 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:07,543] Trial 387 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:07,884] Trial 388 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:08,219] Trial 389 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:08,523] Trial 390 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:08,841] Trial 391 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:09,169] Trial 392 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:09,497] Trial 393 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:09,879] Trial 394 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:10,249] Trial 395 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:10,669] Trial 396 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:11,002] Trial 397 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:11,335] Trial 398 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:11,697] Trial 399 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:12,038] Trial 400 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:12,407] Trial 401 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:12,731] Trial 402 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:13,130] Trial 403 pruned. Trial was pruned at iteration 5.
# [I 2024-06-12 11:34:13,511] Trial 404 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:13,943] Trial 405 pruned. Trial was pruned at iteration 6.
# [I 2024-06-12 11:34:14,264] Trial 406 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:14,603] Trial 407 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:15,004] Trial 408 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:34:15,379] Trial 409 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:16,602] Trial 410 finished with value: -0.5935450394600449 and parameters: {'objective': 'regression_l2', 'boosting_type': 'gbdt', 'lambda_l1': 3.803557197739838e-08, 'lambda_l2': 5.33032258360129e-07, 'num_leaves': 394, 'feature_fraction': 0.9349389609876684, 'bagging_fraction': 0.9669627511127178, 'bagging_freq': 3, 'min_child_samples': 51, 'learning_rate': 0.4495008143541412, 'max_depth': 27, 'min_split_gain': 0.11995017542012566, 'subsample': 0.7120389923292898, 'colsample_bytree': 0.7764565415322784, 'num_iterations': 326}. Best is trial 265 with value: -0.6993705928115532.
# /Users/goncaloabreu/repos/fusionchallenge/virtual/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2024-06-12 11:34:16,862] Trial 411 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:17,182] Trial 412 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:17,520] Trial 413 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:17,902] Trial 414 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:34:18,217] Trial 415 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:18,541] Trial 416 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:18,886] Trial 417 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:19,281] Trial 418 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:19,582] Trial 419 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:19,937] Trial 420 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:20,257] Trial 421 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:20,564] Trial 422 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:20,868] Trial 423 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:21,179] Trial 424 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:21,486] Trial 425 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:21,795] Trial 426 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:22,142] Trial 427 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:22,554] Trial 428 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:22,847] Trial 429 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:23,191] Trial 430 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:23,519] Trial 431 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:23,850] Trial 432 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:24,183] Trial 433 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:24,550] Trial 434 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:24,877] Trial 435 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:25,275] Trial 436 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:34:25,594] Trial 437 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:25,921] Trial 438 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:26,294] Trial 439 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:34:26,600] Trial 440 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:26,927] Trial 441 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:27,239] Trial 442 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:27,580] Trial 443 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:27,920] Trial 444 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:28,254] Trial 445 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:28,583] Trial 446 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:28,911] Trial 447 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:29,266] Trial 448 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:29,590] Trial 449 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:29,950] Trial 450 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:30,266] Trial 451 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:30,610] Trial 452 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:30,969] Trial 453 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:31,299] Trial 454 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:31,688] Trial 455 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:34:32,008] Trial 456 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:32,333] Trial 457 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:32,693] Trial 458 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:34:33,056] Trial 459 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:33,388] Trial 460 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:33,905] Trial 461 pruned. Trial was pruned at iteration 14.
# [I 2024-06-12 11:34:34,280] Trial 462 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:34,612] Trial 463 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:35,090] Trial 464 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:35,442] Trial 465 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:35,760] Trial 466 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:36,229] Trial 467 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:34:36,589] Trial 468 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:36,899] Trial 469 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:37,261] Trial 470 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:37,604] Trial 471 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:37,918] Trial 472 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:38,250] Trial 473 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:38,619] Trial 474 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:38,961] Trial 475 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:39,314] Trial 476 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:39,635] Trial 477 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:39,979] Trial 478 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:40,402] Trial 479 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:34:40,737] Trial 480 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:41,103] Trial 481 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:41,441] Trial 482 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:41,820] Trial 483 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:34:42,199] Trial 484 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:42,563] Trial 485 pruned. Trial was pruned at iteration 1.
# [I 2024-06-12 11:34:42,955] Trial 486 pruned. Trial was pruned at iteration 3.
# [I 2024-06-12 11:34:43,288] Trial 487 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:43,603] Trial 488 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:44,017] Trial 489 pruned. Trial was pruned at iteration 4.
# [I 2024-06-12 11:34:44,391] Trial 490 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:44,784] Trial 491 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:45,165] Trial 492 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:45,544] Trial 493 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:45,873] Trial 494 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:46,276] Trial 495 pruned. Trial was pruned at iteration 2.
# [I 2024-06-12 11:34:46,596] Trial 496 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:46,915] Trial 497 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:47,229] Trial 498 pruned. Trial was pruned at iteration 0.
# [I 2024-06-12 11:34:47,643] Trial 499 pruned. Trial was pruned at iteration 4.
# Best hyperparameters:  {'objective': 'regression_l2', 'boosting_type': 'dart', 'lambda_l1': 3.82633509271862e-08, 'lambda_l2': 6.51512044541533e-05, 'num_leaves': 439, 'feature_fraction': 0.49162472859382134, 'bagging_fraction': 0.9219824165177758, 'bagging_freq': 2, 'min_child_samples': 65, 'learning_rate': 0.5199887797749565, 'max_depth': 21, 'min_split_gain': 0.1576217695589074, 'subsample': 0.654661529996304, 'colsample_bytree': 0.7879778688270193, 'num_iterations': 330}

# %%
study.best_params
# Out:
# {'objective': 'regression_l2',
#  'boosting_type': 'dart',
#  'lambda_l1': 3.82633509271862e-08,
#  'lambda_l2': 6.51512044541533e-05,
#  'num_leaves': 439,
#  'feature_fraction': 0.49162472859382134,
#  'bagging_fraction': 0.9219824165177758,
#  'bagging_freq': 2,
#  'min_child_samples': 65,
#  'learning_rate': 0.5199887797749565,
#  'max_depth': 21,
#  'min_split_gain': 0.1576217695589074,
#  'subsample': 0.654661529996304,
#  'colsample_bytree': 0.7879778688270193,
#  'num_iterations': 330}

# %%
dtrain = lgb.Dataset(train_x, label=train_y)
dvalid = lgb.Dataset(valid_x, label=valid_y, reference=dtrain)    

gbm = lgb.train(study.best_params, dtrain, valid_sets=[dvalid])
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.9219824165177758, subsample=0.654661529996304 will be ignored. Current value: bagging_fraction=0.9219824165177758
# [LightGBM] [Warning] feature_fraction is set=0.49162472859382134, colsample_bytree=0.7879778688270193 will be ignored. Current value: feature_fraction=0.49162472859382134
# [LightGBM] [Warning] bagging_fraction is set=0.9219824165177758, subsample=0.654661529996304 will be ignored. Current value: bagging_fraction=0.9219824165177758
# [LightGBM] [Warning] feature_fraction is set=0.49162472859382134, colsample_bytree=0.7879778688270193 will be ignored. Current value: feature_fraction=0.49162472859382134
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005032 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 173145
# [LightGBM] [Info] Number of data points in the train set: 5196, number of used features: 679
# [LightGBM] [Warning] bagging_fraction is set=0.9219824165177758, subsample=0.654661529996304 will be ignored. Current value: bagging_fraction=0.9219824165177758
# [LightGBM] [Warning] feature_fraction is set=0.49162472859382134, colsample_bytree=0.7879778688270193 will be ignored. Current value: feature_fraction=0.49162472859382134
# [LightGBM] [Info] Start training from score 1.897760
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
preds = gbm.predict(valid_x)
rmse = root_mean_squared_error(valid_y, preds)
rmse
# Out:
# 0.3338153139990821

# %%
R2 = r2_score(valid_y, preds)

plt.figure(figsize=(8, 8))
plt.plot(valid_y, preds, '.')
plt.plot([-2, 4], [-2, 4], ':k')
plt.xlabel("Actual log(Q) from GX")
plt.ylabel("Predicted log(Q)")
plt.title(f"Nonlinear GX turbulence calculations, linear regression using cvdrift: $R^2$ = {R2:.3}")
# Out:
# Text(0.5, 1.0, 'Nonlinear GX turbulence calculations, linear regression using cvdrift: $R^2$ = 0.699')

# %%
# Define the number of top features to plot
top_n_features = 20  # Change this value to display more or fewer features

# Plot feature importance using Gain
ax = lgb.plot_importance(gbm, importance_type="gain", max_num_features=top_n_features, figsize=(10, 8))
ax.set_title("LightGBM Feature Importance (Gain)")
plt.show()

# %%
explainer = shap.TreeExplainer(gbm)
shap_values = explainer(features)

# %%
shap.summary_plot(shap_values, features, max_display=top_n_features)
